# %%
import numpy as np
from keras import utils
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.datasets import mnist

# Load data from MNIST dataset
(x_train, train_label), (x_test, test_label) = mnist.load_data()

# Flatten the 28*28 matrices to a 784 length 1D array
train_shape = x_train.shape
test_shape = x_test.shape
x_train = x_train.reshape(train_shape[0],train_shape[1]*train_shape[2])
x_test = x_test.reshape(test_shape[0],test_shape[1]*test_shape[2])

# Normalize the data
x_train = utils.normalize(x_train)
x_test = utils.normalize(x_test)

# Convert the vector of integer labels to a binary matrix
y_train = utils.to_categorical(train_label)
y_test = utils.to_categorical(test_label)

# Split the training data into training and validation
no_of_train_samples = int(0.8*x_train.shape[0])
x_val = x_train[no_of_train_samples:,:]
y_val = y_train[no_of_train_samples:]
x_train = x_train[:no_of_train_samples,:]
y_train = y_train[:no_of_train_samples]

# %%
import matplotlib.pyplot as plt

# Function to plot the loss and accuracy of a model
def plot_results(history):
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()
    
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
# Define and train a model 
model1 = Sequential([
    Dense(250, input_shape=(784,)),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])
model1.compile(optimizer='adadelta',loss='categorical_crossentropy', metrics=['accuracy'])
history1 = model1.fit(x_train, y_train, epochs=40, validation_data=(x_val,y_val), batch_size = 32)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/40
# 48000/48000 [==============================] - 9s - loss: 0.5997 - acc: 0.8548 - val_loss: 0.3174 - val_acc: 0.9107
# Epoch 2/40
# 48000/48000 [==============================] - 9s - loss: 0.3090 - acc: 0.9118 - val_loss: 0.2687 - val_acc: 0.9231
# Epoch 3/40
# 48000/48000 [==============================] - 9s - loss: 0.2654 - acc: 0.9241 - val_loss: 0.2374 - val_acc: 0.9329
# Epoch 4/40
# 48000/48000 [==============================] - 9s - loss: 0.2361 - acc: 0.9325 - val_loss: 0.2177 - val_acc: 0.9394
# Epoch 5/40
# 48000/48000 [==============================] - 9s - loss: 0.2129 - acc: 0.9386 - val_loss: 0.2003 - val_acc: 0.9448
# Epoch 6/40
# 48000/48000 [==============================] - 9s - loss: 0.1944 - acc: 0.9436 - val_loss: 0.1860 - val_acc: 0.9487
# Epoch 7/40
# 48000/48000 [==============================] - 9s - loss: 0.1788 - acc: 0.9480 - val_loss: 0.1760 - val_acc: 0.9503
# Epoch 8/40
# ...

# %%
# Define and train a model 
model2 = Sequential([
    Dense(100, input_shape=(784,)),
    Activation('relu'),
    Dense(40),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])
model2.compile(optimizer='adadelta',loss='categorical_crossentropy', metrics=['accuracy'])
history2 = model2.fit(x_train, y_train, epochs=50, validation_data=(x_val,y_val), batch_size = 32)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/50
# 48000/48000 [==============================] - 4s - loss: 0.5579 - acc: 0.8441 - val_loss: 0.3027 - val_acc: 0.9138
# Epoch 2/50
# 48000/48000 [==============================] - 4s - loss: 0.2932 - acc: 0.9158 - val_loss: 0.2556 - val_acc: 0.9273
# Epoch 3/50
# 48000/48000 [==============================] - 4s - loss: 0.2462 - acc: 0.9276 - val_loss: 0.2198 - val_acc: 0.9373
# Epoch 4/50
# 48000/48000 [==============================] - 4s - loss: 0.2126 - acc: 0.9376 - val_loss: 0.1983 - val_acc: 0.9433
# Epoch 5/50
# 48000/48000 [==============================] - 4s - loss: 0.1882 - acc: 0.9450 - val_loss: 0.1794 - val_acc: 0.9478
# Epoch 6/50
# 48000/48000 [==============================] - 4s - loss: 0.1685 - acc: 0.9509 - val_loss: 0.1669 - val_acc: 0.9523
# Epoch 7/50
# 48000/48000 [==============================] - 4s - loss: 0.1527 - acc: 0.9551 - val_loss: 0.1546 - val_acc: 0.9555
# Epoch 8/50
# ...

# %%
plot_results(history2)

# %%
# Define and train a model 
model3 = Sequential([
    Dense(100, input_shape=(784,)),
    Activation('relu'),
    Dense(50),
    Activation('relu'),
    Dense(20),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])
model3.compile(optimizer='adadelta',loss='categorical_crossentropy', metrics=['accuracy'])
history3 = model3.fit(x_train, y_train, epochs=30 validation_data=(x_val,y_val), batch_size = 32)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/40
# 48000/48000 [==============================] - 4s - loss: 0.5644 - acc: 0.8264 - val_loss: 0.3004 - val_acc: 0.9133
# Epoch 2/40
# 48000/48000 [==============================] - 4s - loss: 0.2818 - acc: 0.9179 - val_loss: 0.2367 - val_acc: 0.9303
# Epoch 3/40
# 48000/48000 [==============================] - 4s - loss: 0.2260 - acc: 0.9346 - val_loss: 0.1986 - val_acc: 0.9423
# Epoch 4/40
# 48000/48000 [==============================] - 4s - loss: 0.1882 - acc: 0.9445 - val_loss: 0.1729 - val_acc: 0.9521
# Epoch 5/40
# 48000/48000 [==============================] - 4s - loss: 0.1618 - acc: 0.9527 - val_loss: 0.1547 - val_acc: 0.9563
# Epoch 6/40
# 48000/48000 [==============================] - 4s - loss: 0.1424 - acc: 0.9576 - val_loss: 0.1462 - val_acc: 0.9589
# Epoch 7/40
# 48000/48000 [==============================] - 4s - loss: 0.1273 - acc: 0.9627 - val_loss: 0.1315 - val_acc: 0.9611
# Epoch 8/40
# ...

# %%
# Choose the best model and evaluate model using test data
loss_and_metrics = model2.evaluate(x_test, y_test, batch_size=32, verbose=0)
print "Percentage accuracy on test data: "+ str(100*loss_and_metrics[1])+"%"
# Out:
# Percentage accuracy on test data: 97.65%
